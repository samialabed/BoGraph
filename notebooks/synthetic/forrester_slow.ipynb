# %%
import numpy as np


def original(x):
    return np.power(6 * x - 2, 2) * np.sin(12 * x - 4)


def alternative_form(x):
    return 0.5 * original(x) + 10 * (x - 0.5) + 5


np.array2
f1 = original(np.linspace(0, 1, 10000))
f2 = alternative_form(np.linspace(0, 1, 10000))
y = f1 + f2

# %%
mean = np.asarray(
    [
        [-0.40431840970019817],
        [-0.15191525348749746],
        [-0.1278461625342926],
        [-0.3445842887150432],
        [-1.6935482895960332],
        [-0.33206472908863827],
        [-0.11441683669685698],
        [-0.15192626444491975],
        [1.3047669537093656],
        [-0.25956235599667377],
        [-0.15160888622080915],
        [3.9781777696754874],
        [-1.3967290052375985],
        [-1.0514476478853352],
        [-0.015967205257520156],
        [-0.5685407573471322],
        [3.9780819943061987],
        [0.057043157914283604],
        [-0.18672290973918404],
        [0.19080478268927425],
        [-0.1857159182797501],
        [0.017199910784374772],
        [-0.24822289324272173],
        [-0.390123274632141],
        [-1.647837346897286],
        [-0.5781886962817238],
        [-0.3998580411992192],
        [0.09535402786554403],
        [3.946707608025979],
        [0.19206399720805667],
        [1.353999800404158],
        [-0.1597704939877458],
        [-0.18594517859089432],
        [-1.6203566685090847],
        [-0.09245081212153661],
        [-0.16293537243871992],
        [-0.37902467024801023],
        [1.686598110396976],
        [-0.08382868092261742],
        [0.4374273876965775],
    ]
)

rand_like = np.asarray(
    [
        [0.1393],
        [0.3380],
        [0.3954],
        [0.1876],
        [0.7580],
        [0.1931],
        [0.4061],
        [0.3324],
        [0.8997],
        [0.6079],
        [0.3476],
        [0.9970],
        [0.8018],
        [0.6765],
        [0.4551],
        [0.8426],
        [0.9970],
        [0.5551],
        [0.2625],
        [0.8680],
        [0.2633],
        [0.5662],
        [0.2286],
        [0.1240],
        [0.7751],
        [0.6384],
        [0.1540],
        [0.5119],
        [0.9950],
        [0.0349],
        [0.9011],
        [0.2915],
        [0.2631],
        [0.7331],
        [0.4198],
        [0.2863],
        [0.1703],
        [0.9103],
        [0.4245],
        [0.8753],
    ]
)

# %%
mean.T[]
# Out:
# array([[-0.40431841, -0.15191525, -0.12784616, -0.34458429, -1.69354829,
#         -0.33206473, -0.11441684, -0.15192626,  1.30476695, -0.25956236,
#         -0.15160889,  3.97817777, -1.39672901, -1.05144765, -0.01596721,
#         -0.56854076,  3.97808199,  0.05704316, -0.18672291,  0.19080478,
#         -0.18571592,  0.01719991, -0.24822289, -0.39012327, -1.64783735,
#         -0.5781887 , -0.39985804,  0.09535403,  3.94670761,  0.192064  ,
#          1.3539998 , -0.15977049, -0.18594518, -1.62035667, -0.09245081,
#         -0.16293537, -0.37902467,  1.68659811, -0.08382868,  0.43742739]])

# %%
from matplotlib import pyplot as plt

rand_like.sort()
plt.plot(rand_like, mean, c="blue")
plt.plot(rand_like, original(rand_like), c="red")

# %%
original(0.7722594607621431) + alternative_form(0.2040724428370595)
# Out:
# -4.155562219400337

# %%
x1, x2 = np.meshgrid(np.linspace(0, 1, 10000), np.linspace(0, 1, 10000))

y = original(x1) + alternative_form(x2)

# %%
y.min()
# Out:
# -5.355644513470416

# %%
y.min()
# Out:
# -1.4904249258986972

# %%
f1.min()
# Out:
# -6.020739667320624

# %%
f2.min()
# Out:
# 0.6650951538502081

# %%
from matplotlib import pyplot as plt

plt.plot(np.linspace(0, 1, 1000), y, c="red")

plt.plot(np.linspace(0, 1, 1000), f1, c="blue")

plt.plot(np.linspace(0, 1, 1000), f2, c="green")

# %%
original(0.38793735597288836) + alternative_form(0.1612460094677275)
# Out:
# 1.2086076899457003

# %%
Xs = {Tensor: (5, 2)} tensor([[5.5985e-01, 3.1277e-01],\n        [8.5820e-04, 4.7024e-01],\n        [4.4528e-01, 7.4564e-01],\n        [5.8380e-01, 4.9583e-01],\n        [9.2052e-01, 1.5677e-02]], dtype=torch.float64)
Ys = {Tensor: (5, 1)} tensor([[ 1.0684],\n        [-0.6357],\n        [ 0.6420],\n        [ 0.3185],\n        [-1.3932]], dtype=torch.float64)

Xs = {Tensor: (5, 2)} tensor([[0.7647, 0.0303],\n        [0.5259, 0.1606],\n        [0.0395, 0.7848],\n        [0.6391, 0.2106],\n        [0.5121, 0.2998]], dtype=torch.float64)
Ys = {Tensor: (5, 1)} tensor([[-1.5156],\n        [ 0.1452],\n        [ 1.1144],\n        [-0.3233],\n        [ 0.5792]], dtype=torch.float64)
