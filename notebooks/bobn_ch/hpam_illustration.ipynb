# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from autorocks.viz import plots_setup
import torch
import gpytorch
import botorch.posteriors
from botorch import models
from botorch.optim import fit
import torch
import numpy as np
import pandas as pd
import botorch
import daft

output_location = "/Users/salabed/workspace/latex_writings/thesis/phd_dissertation/Chapters/BoBn/Figures/"
plt.style.use("ggplot")
sns.set_theme(style="ticks", rc={"axes.spines.right": False, "axes.spines.top": False})
sns.set_context("paper")  # , font_scale=1.5, rc={"lines.linewidth": 1.5})
plt.rcParams["svg.fonttype"] = "none"
plt.rcParams["font.family"] = "Arial"
plt.rc("text", usetex=False)
plt.rc("xtick", labelsize="large")
plt.rc("ytick", labelsize="large")
plt.rc("axes", labelsize="large")
plt.rc("pdf", use14corefonts=True)

# %%
# Instantiate the PGM.
pgm = daft.PGM()

pgm.add_node("type", "Cache\nType", 0, 0, scale=1.25)
pgm.add_node("size", "Cache\nSize", 1, 0, scale = 1.25)
pgm.add_node("lat", "Latency", 2, 0, scale = 1.25, observed = True)
pgm.add_edge(f"type", "size")
pgm.add_edge(f"size", "lat")

# Render and save.
output_format = "pdf"

pgm.render(dpi=300).figure.savefig(f"{output_location}/hpam_exampl.{output_format}", bbox_inches="tight", format=f"{output_format}", dpi=300)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
